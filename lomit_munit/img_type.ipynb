# %%
# !rm -rf /network/tmp1/ccai/data/deeplab_segmented_houses/
# Out:
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/ludwigstr_hockenheim_house_facade_construction_site_clay_bricks_building_structure-873087.jpg!d.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/G_Street_DC_CHHD.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/street-3176461_960_720.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/file0001039753380.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/bronte-creek-state-park-347266_960_720.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/west-2333252_960_720.png': Permission denied
# rm: cannot remove '/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/Доходный_дом_улица_Леваневского_04.png': Permission denied
# ...

# %%
import cv2
import numpy as np
import os

# %%
list1 = os.listdir('/network/tmp1/ccai/inference_data/munit/depth_floods_280/testA/')

# %%
img = cv2.imread('/network/tmp1/ccai/data/deeplab_segmented_houses/houses_mask/0001_274567967_large.png')

# %%
list1
# Out:
# ['d656982cceab840a4dc314080edfe256_0.png',
#  'luxury-home-2409518_960_720_0.png',
#  'beautiful_cottage_estate_garden_grass_home_house_nice-1153179.jpg!d.png',
#  '1280px-Jersikas_iela_18_0.png',
#  'new_home_for_sale_home_house_mortgage_sell_buy_real_estate-569321.jpg!d_0.png',
#  'plantation_historic_building_house_public_park_1855_fluvanna-1256915.jpg!d_0.png',
#  'netherlands_house_home_architecture_residence_road_trees_summer-1102155.jpg!d.png',
#  'mansfield_richland_county_ohio_house_property_building_front_exterior-706769.jpg!d_0.png',
#  'country_houses_bungalows_baltic_sea_ko_obrzeg_poland-922424.jpg!d_0.png',
#  'english_village_street_scene_eclectic_architecture_telegraph_pole_overhead_phone_lines_blue_sky-728433.jpg!d_0.png',
#  '1800s_street1.png',
#  'new_home_construction_industry_for_sale_buy_sell_house_estate-491763.jpg!d_0.png',
#  'truss_fachwerkh_user_cobblestones_goslar_imperial_city_resin_lower_saxony_germany-886207.jpg!d.png',
# ...

# %%
img = cv2.imread('/network/tmp1/ccai/inference_data/instagan/depth_floods_280/trainA_seg_modified/new_home_for_sale_real_estate_house_estate_sale_real_new-486526.jpg!d_0.png')

# %%
img
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-32ad6cb7aa56> in <module>
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
np.unique(img)
# Out:
# array([None], dtype=object)

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
np.unique(thresh1)
# Out:
# array([  0, 255], dtype=uint8)

# %%
list1
# Out:
# ['d656982cceab840a4dc314080edfe256_0.png',
#  'luxury-home-2409518_960_720_0.png',
#  'beautiful_cottage_estate_garden_grass_home_house_nice-1153179.jpg!d.png',
#  '1280px-Jersikas_iela_18_0.png',
#  'new_home_for_sale_home_house_mortgage_sell_buy_real_estate-569321.jpg!d_0.png',
#  'plantation_historic_building_house_public_park_1855_fluvanna-1256915.jpg!d_0.png',
#  'netherlands_house_home_architecture_residence_road_trees_summer-1102155.jpg!d.png',
#  'mansfield_richland_county_ohio_house_property_building_front_exterior-706769.jpg!d_0.png',
#  'country_houses_bungalows_baltic_sea_ko_obrzeg_poland-922424.jpg!d_0.png',
#  'english_village_street_scene_eclectic_architecture_telegraph_pole_overhead_phone_lines_blue_sky-728433.jpg!d_0.png',
#  '1800s_street1.png',
#  'new_home_construction_industry_for_sale_buy_sell_house_estate-491763.jpg!d_0.png',
#  'truss_fachwerkh_user_cobblestones_goslar_imperial_city_resin_lower_saxony_germany-886207.jpg!d.png',
# ...

# %%
mask = cv2.imread(folder + mask_path, cv2.IMREAD_UNCHANGED)
            ret, thresh = cv2.threshold(mask, 127, 1, cv2.THRESH_BINARY)
            cv2.imwrite(out_folder + mask_path, thresh)

# %%
for item in list1:
    if item[-6:] == '_0.png':
        img = cv2.imread('/network/tmp1/ccai/inference_data/munit/depth_floods_280/testA/'+item)
        ret,thresh = cv2.threshold(img,127,1,cv2.THRESH_BINARY)
        cv2.imwrite('/network/tmp1/ccai/inference_data/munit/depth_floods_280/testA/'+item,thresh)

# %%
np.unique(cv2.imread('/network/tmp1/ccai/inference_data/munit/depth_floods_280/trainA/sukhanova_st_6_0.png'))
# Out:
# array([0, 1], dtype=uint8)

# %%
img = cv2.imread('/network/tmp1/ccai/inference_data/munit/depth_floods_280/trainA_seg/'+item, cv2.IMREAD_UNCHANGED)

# %%
img.shape
https://drive.google.com/open?id=1bwa2V73fGnQyEC1q02D2N5Fe6-4KHIk1
# Out:
# (512, 512, 4)

# %%
from google_drive_downloader import GoogleDriveDownloader as gdd
gdd.download_file_from_google_drive(file_id="1bwa2V73fGnQyEC1q02D2N5Fe6-4KHIk1",dest_path="/network/tmp1/ccai/data/deeplabsegmentedhouses.zip",unzip=True)
# Out:
# ...
# Unzipping...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-76-1963c1a12931> in <module>
#       1 from google_drive_downloader import GoogleDriveDownloader as gdd
# ----> 2 gdd.download_file_from_google_drive(file_id="1bwa2V73fGnQyEC1q02D2N5Fe6-4KHIk1",dest_path="/network/tmp1/ccai/data/deeplabsegmentedhouses.zip",unzip=True)
#
# ~/.conda/envs/python3_6_env/lib/python3.6/site-packages/google_drive_downloader/google_drive_downloader.py in download_file_from_google_drive(file_id, dest_path, overwrite, unzip, showsize)
#      73                     stdout.flush()
#      74                     with zipfile.ZipFile(dest_path, 'r') as z:
# ---> 75                         z.extractall(destination_directory)
#      76                     print('Done.')
#      77                 except zipfile.BadZipfile:
#
# ...

# %%
list1 = os.listdir('/network/tmp1/ccai/inference_data/munit/depth_floods_280/210_flooded_houses/masks')

# %%
len(list1)
# Out:
# 210

# %%
list1
# Out:
# ['100.png',
#  'Flooded_Eagle_Street_in_Brisbane.png',
#  '5.png',
#  'Flooded_Stevens_Street_in_Yeronga,_between_Yeronga_and_Cook_Streets.png',
#  '107.png',
#  '406895923_e58d4227a7_z.png',
#  'file0001290628830.png',
#  '8155031913_87d61354c9_z.png',
#  'dba4be7dbe4e5165219d080ab5dfa0c1.png',
#  'Saintes_-_Inondation_-_1982-12_-_06.png',
#  '35.png',
#  '8030315220_a7cec4d3ff_b.png',
#  '513.png',
#  'file00098157055.png',
#  'file0001311647650.png',
#  'Inondation_du_31_mai_2016_à_Saint-Rémy-lès-Chevreuse_-_11.png',
#  '6311647831_dfa27e003b_z.png',
#  '3754142195_150c963ac2_z.png',
#  '91281527_323ca708d8_z.png',
#  '877.png',
#  'Inondation_02_03_2002_centre_ville.png',
#  '695.png',
#  'guerneville_neon_california_21128_h.png',
#  'file000322768045.png',
#  'file0001494297132.png',
#  '470.png',
#  'Screenshot_2019-02-25 river house.png',
#  '18.png',
#  '545.png',
#  '461.png',
#  '317.png',
#  'GOPR2048.png',
#  'Storm_in_Perth_-_Cars_flooded.png',
# ...

# %%
for item in list1:
    filename, file_extension = os.path.splitext(item)
    filename = filename+"_0"
    os.rename('/network/tmp1/ccai/inference_data/munit/depth_floods_280/210_flooded_houses/masks/'+item,'/network/tmp1/ccai/inference_data/munit/depth_floods_280/210_flooded_houses/masks/'+filename+file_extension)

# %%
img = cv2.imread('/network/tmp1/ccai/inference_data/munit/depth_floods_280/testA/d656982cceab840a4dc314080edfe256_0.png')

# %%
np.unique(img)
# Out:
# array([0, 1], dtype=uint8)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
str1 = 'd656982cceab840a4dc314080edfe256_0.png'

# %%
str1[-6:]
# Out:
# '_0.png'
