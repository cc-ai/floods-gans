# %%
# !pwd
# Out:
# /network/home/bansalsa/lomit-munit/lomit_munit

# %%
# !ls
# Out:
# Dockerfile	   __pycache__	     list_testB.flist	test.py
# LICENSE.md	   configs	     list_trainA.flist	test_batch.py
# LOMIT-MUNIT.ipynb  data		     list_trainB.flist	train.py
# Makefile	   data.py	     logs		trainer.py
# Makefile.cfg	   data_seg.py	     networks.py	utils.py
# README.md	   datasets	     outputs
# TUTORIAL.md	   img_type.ipynb    requirements.txt
# USAGE.md	   list_testA.flist  setup.py

# %%
# !python train.py --config configs/street2flood_list.yaml
# Out:
# /network/home/bansalsa/lomit-munit/lomit_munit/utils.py:98: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(stream)
# Creating directory: ./outputs/street2flood_list/190628_163742/images
# Creating directory: ./outputs/street2flood_list/190628_163742/checkpoints
# /network/home/bansalsa/.conda/envs/python3_6_env/lib/python3.6/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# Elapsed time in update: 1.347570
# Iteration: 00000001/01000000
# Elapsed time in update: 0.188909
# Iteration: 00000002/01000000
# Elapsed time in update: 1.112182
# Iteration: 00000003/01000000
# Elapsed time in update: 0.189507
# Iteration: 00000004/01000000
# Elapsed time in update: 1.118951
# ...
