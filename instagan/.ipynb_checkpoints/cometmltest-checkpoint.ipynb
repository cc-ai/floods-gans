# %%
# !pwd
# Out:
# /network/home/bansalsa/instagan2

# %%
# !ls
# Out:
# LICENSE		 checkpoints  environment.yml  requirements.txt  train.py
# README.md	 data	      imgs	       results		 util
# Untitled.ipynb	 datasets     models	       scripts
# Untitled2.ipynb  docs	      options	       test.py

# %%
# !nvidia-smi
# Out:
# Thu Jun  6 16:53:08 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.48                 Driver Version: 410.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:84:00.0 Off |                  Off |
# | N/A   57C    P0    63W / 149W |      0MiB / 12206MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla K80           Off  | 00000000:85:00.0 Off |                  Off |
# | N/A   42C    P0    75W / 149W |      0MiB / 12206MiB |      0%      Default |
# ...

# %%
# !python train.py --dataroot ./datasets/test_dataset --model insta_gan --name test_dataset_exp_with_cometml_instagan --loadSizeH 330 --loadSizeW 220 --fineSizeH 300 --fineSizeW 200 --niter 400 --niter_decay 200 --batch_size 4 --gpu_ids 0,1,2,3
# Out:
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/bsahil29/ccai-instagan/d3209d3d7b2f49598a2051fe8f02a00e
#
# ----------------- Options ---------------
#                batch_size: 4                             	[default: 1]
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: ./datasets/test_dataset       	[default: None]
#              dataset_mode: unaligned_seg
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 6
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                 fineSizeH: 300                           	[default: 200]
#                 fineSizeW: 200
#                   gpu_ids: 0,1,2,3                       	[default: 0]
# ...

# %%
import comet_ml
